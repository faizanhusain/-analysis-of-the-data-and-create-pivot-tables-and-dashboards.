# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.linear_model import LinearRegression

# %%
train=pd.read_excel(r'C:\\Users\farma\Downloads\Telegram Desktop\start tech acadmey\task 1\problem 3\Data_file.xlsx',header=2)
test=pd.read_excel(r'C:\\Users\farma\Downloads\Telegram Desktop\start tech acadmey\task 1\problem 3\Test_data_file.xlsx')

# %%
train.head()
# Out:
#    S.No. College       Role  City type  Previous CTC  Previous job changes  \
# 0      1  Tier 1    Manager  Non-Metro         55523                     3
# 1      2  Tier 2  Executive      Metro         57081                     1
# 2      3  Tier 2  Executive      Metro         60347                     2
# 3      4  Tier 3  Executive      Metro         49010                     2
# 4      5  Tier 3  Executive      Metro         57879                     4
#
#    Graduation marks  Exp (Months)           CTC
# 0                66            19  71406.576531
# 1                84            18  68005.870631
# 2                52            28  76764.020277
# 3                81            33  82092.386880
# 4                74            32  73878.097729

# %%
test
# Out:
#      College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0     Tier 1    Manager  Non-Metro           1           0             1
# 1     Tier 2  Executive      Metro           0           1             0
# 2     Tier 2  Executive      Metro           0           1             0
# 3     Tier 3  Executive      Metro           0           0             0
# 4     Tier 3  Executive      Metro           0           0             0
# ...      ...        ...        ...         ...         ...           ...
# 1333  Tier 3  Executive      Metro           0           0             0
# 1334  Tier 1  Executive  Non-Metro           1           0             0
# 1335  Tier 2  Executive  Non-Metro           0           1             0
# 1336  Tier 1  Executive  Non-Metro           1           0             0
# 1337  Tier 3    Manager  Non-Metro           0           0             1
#
#       City_Metro  previous CTC  previous job changes  Graduation marks  ...  \
# ...

# %%
test.isnull().sum()
# Out:
# College                    0
# Role                       0
# City type                  0
# College_T1                 0
# College_T2                 0
# Role_Manager               0
# City_Metro                 0
# previous CTC               0
# previous job changes       0
# Graduation marks           0
# Exp                        0
# Actual CTC                 0
# Predicted CTC           1338
# Unnamed: 13             1338
# Unnamed: 14             1338
# Unnamed: 15             1337
# Unnamed: 16             1337
# Unnamed: 17             1337
# Unnamed: 18             1337
# Unnamed: 19             1337
# Unnamed: 20             1337
# Unnamed: 21             1337
# Unnamed: 22             1337
# Unnamed: 23             1337
# dtype: int64

# %%
test=test.dropna(axis=1)

# %%
test.isnull().sum()
# Out:
# College                 0
# Role                    0
# City type               0
# College_T1              0
# College_T2              0
# Role_Manager            0
# City_Metro              0
# previous CTC            0
# previous job changes    0
# Graduation marks        0
# Exp                     0
# Actual CTC              0
# dtype: int64

# %%
train=train.drop('S.No.',axis=1)

# %%
train
# Out:
#      College       Role  City type  Previous CTC  Previous job changes  \
# 0     Tier 1    Manager  Non-Metro         55523                     3
# 1     Tier 2  Executive      Metro         57081                     1
# 2     Tier 2  Executive      Metro         60347                     2
# 3     Tier 3  Executive      Metro         49010                     2
# 4     Tier 3  Executive      Metro         57879                     4
# ...      ...        ...        ...           ...                   ...
# 1333  Tier 3  Executive      Metro         59661                     4
# 1334  Tier 1  Executive  Non-Metro         53714                     1
# 1335  Tier 2  Executive  Non-Metro         61957                     1
# 1336  Tier 1  Executive  Non-Metro         53203                     3
# 1337  Tier 3    Manager  Non-Metro         51820                     1
#
#       Graduation marks  Exp (Months)           CTC
# 0                   66            19  71406.576531
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   College               1338 non-null   object
#  1   Role                  1338 non-null   object
#  2   City type             1338 non-null   object
#  3   Previous CTC          1338 non-null   int64
#  4   Previous job changes  1338 non-null   int64
#  5   Graduation marks      1338 non-null   int64
#  6   Exp (Months)          1338 non-null   int64
#  7   CTC                   1338 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 83.8+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   College               1338 non-null   object
#  1   Role                  1338 non-null   object
#  2   City type             1338 non-null   object
#  3   College_T1            1338 non-null   int64
#  4   College_T2            1338 non-null   int64
#  5   Role_Manager          1338 non-null   int64
#  6   City_Metro            1338 non-null   int64
#  7   previous CTC          1338 non-null   int64
#  8   previous job changes  1338 non-null   int64
#  9   Graduation marks      1338 non-null   int64
#  10  Exp                   1338 non-null   int64
#  11  Actual CTC            1338 non-null   float64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 125.6+ KB

# %%
train.isnull().sum().sum()
# Out:
# 0

# %%
train.duplicated().sum()
# Out:
# 0

# %%
#Converting the categorical features into numerical
#train=pd.get_dummies(columns=['College','Role','City type'],data=train)
train=pd.get_dummies(train)
train
# Out:
#       Previous CTC  Previous job changes  Graduation marks  Exp (Months)  \
# 0            55523                     3                66            19
# 1            57081                     1                84            18
# 2            60347                     2                52            28
# 3            49010                     2                81            33
# 4            57879                     4                74            32
# ...            ...                   ...               ...           ...
# 1333         59661                     4                68            50
# 1334         53714                     1                67            18
# 1335         61957                     1                47            18
# 1336         53203                     3                69            21
# 1337         51820                     1                47            61
#
#                CTC  College_Tier 1  College_Tier 2  College_Tier 3  \
# ...

# %%
# Fixing the dummy variable issue in the train dataset wrt to test data
drop_list =['College_Tier 3','City type_Non-Metro','Role_Executive']
train.drop(drop_list,axis=1,inplace=True)

# %%
#droping unnecessary variables in test dataset
drop_list2=['College','Role','City type']
test.drop(drop_list2,axis=1,inplace=True)
# Out:
# C:\Users\farma\AppData\Local\Temp\ipykernel_11188\1879160192.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.drop(drop_list2,axis=1,inplace=True)

# %%
test
# Out:
#       College_T1  College_T2  Role_Manager  City_Metro  previous CTC  \
# 0              1           0             1           0         55523
# 1              0           1             0           1         57081
# 2              0           1             0           1         60347
# 3              0           0             0           1         49010
# 4              0           0             0           1         57879
# ...          ...         ...           ...         ...           ...
# 1333           0           0             0           1         59661
# 1334           1           0             0           0         53714
# 1335           0           1             0           0         61957
# 1336           1           0             0           0         53203
# 1337           0           0             1           0         51820
#
#       previous job changes  Graduation marks  Exp    Actual CTC
# 0                        3                66   19  71406.576531
# ...

# %%
train
# Out:
#       Previous CTC  Previous job changes  Graduation marks  Exp (Months)  \
# 0            55523                     3                66            19
# 1            57081                     1                84            18
# 2            60347                     2                52            28
# 3            49010                     2                81            33
# 4            57879                     4                74            32
# ...            ...                   ...               ...           ...
# 1333         59661                     4                68            50
# 1334         53714                     1                67            18
# 1335         61957                     1                47            18
# 1336         53203                     3                69            21
# 1337         51820                     1                47            61
#
#                CTC  College_Tier 1  College_Tier 2  Role_Manager  \
# ...

# %%
#Now spliting the dataset to train the model
x_train=train.drop('CTC',axis=1)
y_train=train['CTC']
x_test=test.drop('Actual CTC',axis=1)
y_test=test['Actual CTC']

# %%
x_train
# Out:
#       Previous CTC  Previous job changes  Graduation marks  Exp (Months)  \
# 0            55523                     3                66            19
# 1            57081                     1                84            18
# 2            60347                     2                52            28
# 3            49010                     2                81            33
# 4            57879                     4                74            32
# ...            ...                   ...               ...           ...
# 1333         59661                     4                68            50
# 1334         53714                     1                67            18
# 1335         61957                     1                47            18
# 1336         53203                     3                69            21
# 1337         51820                     1                47            61
#
#       College_Tier 1  College_Tier 2  Role_Manager  City type_Metro
# ...

# %%
x_test
# Out:
#       College_T1  College_T2  Role_Manager  City_Metro  previous CTC  \
# 0              1           0             1           0         55523
# 1              0           1             0           1         57081
# 2              0           1             0           1         60347
# 3              0           0             0           1         49010
# 4              0           0             0           1         57879
# ...          ...         ...           ...         ...           ...
# 1333           0           0             0           1         59661
# 1334           1           0             0           0         53714
# 1335           0           1             0           0         61957
# 1336           1           0             0           0         53203
# 1337           0           0             1           0         51820
#
#       previous job changes  Graduation marks  Exp
# 0                        3                66   19
# ...

# %%
x_test.isnull().sum().sum()
# Out:
# 0

# %%
#feature scaling-----standardization
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-0.00879267,  0.42257741,  0.4103073 , ..., -0.61132367,
#          1.97058663, -1.0105187 ],
#        [ 0.22433261, -1.35823699,  1.61924306, ...,  1.63579466,
#         -0.5074631 ,  0.98959079],
#        [ 0.71302785, -0.46782979, -0.52997607, ...,  1.63579466,
#         -0.5074631 ,  0.98959079],
#        ...,
#        [ 0.95393396, -1.35823699, -0.86579156, ...,  1.63579466,
#         -0.5074631 , -1.0105187 ],
#        [-0.35593687,  0.42257741,  0.61179659, ..., -0.61132367,
#         -0.5074631 , -1.0105187 ],
#        [-0.56287671, -1.35823699, -0.86579156, ..., -0.61132367,
#          1.97058663, -1.0105187 ]])

# %%
x_test
# Out:
# array([[ 1.0303559 , -0.61132367,  1.97058663, ...,  0.42257741,
#          0.4103073 , -1.43876426],
#        [-0.97053843,  1.63579466, -0.5074631 , ..., -1.35823699,
#          1.61924306, -1.50996545],
#        [-0.97053843,  1.63579466, -0.5074631 , ..., -0.46782979,
#         -0.52997607, -0.79795355],
#        ...,
#        [-0.97053843,  1.63579466, -0.5074631 , ..., -1.35823699,
#         -0.86579156, -1.50996545],
#        [ 1.0303559 , -0.61132367, -0.5074631 , ...,  0.42257741,
#          0.61179659, -1.29636188],
#        [-0.97053843, -0.61132367,  1.97058663, ..., -1.35823699,
#         -0.86579156,  1.55168573]])

# %% [markdown]
# # Linear Regression

# %%
# Model creation
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Prediction--test data
y_pred=model.predict(x_test)
y_pred
# Out:
# array([74900.00874261, 86698.69107286, 72168.69201421, ...,
#        61709.40062068, 76091.00378086, 64361.85874602])

# %% [markdown]
# # Evaulation

# %%
y_test.shape
# Out:
# (1338,)

# %%
y_pred.shape
# Out:
# (1338,)

# %%
from sklearn.metrics import mean_squared_error

# %%
print('Mean Square Error is ',mean_squared_error(y_test,y_pred))
# Out:
# Mean Square Error is  190236801.27795473
